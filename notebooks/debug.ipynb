# %%
from utils import get_dataframes

dataframes = get_dataframes()
dataframes["characters"]
# Out:
#           name        surname                              title       race  \
# 0       Adamar                                 Mysteriöser Hüter      Elfen
# 1       Adrian  von Waldegrav  Leidenschaftlicher Schätzesammler   Menschen
# 2        Aelua                        Junggebliebene Dorfälteste      Elfen
# 3       Alcuin                       Rachsüchtiger Seelenschmied     Götter
# 4        Alden                          Weltoffener Kutschfahrer   Menschen
# ..         ...            ...                                ...        ...
# 137       Volo                                                        Elfen
# 138    Wirkung                           Verführerischer Abgrund  Tieflinge
# 139      Zetta                          Verletzliches Pflänzchen  Halbelfen
# 140       Zora                             Nachfahrin des Meeres      Nixen
# 141  Rosalinde                  Sadistische Märtyrerin Justicias   Menschen
#
# ...

# %%
a = True
b = ~a
print(b)
# Out:
# False

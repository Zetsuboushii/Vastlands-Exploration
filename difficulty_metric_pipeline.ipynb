# %%
# Step 1: get all data
from utils import get_dataframes

#todo as effects is now a proper format it will be inside of dataframes and not separate
dataframes, effect_data = get_dataframes("", True, False)

# %% [markdown]
# ### Strength Metric Calculation
#
# To evaluate the strength of an ability, we incorporate several factors: damage, effects, cooldown, and area of effect (AoE). Each factor contributes to a final score that reflects the overall potency of the ability.
#
# #### Variables:
#
# - **$ \text{AvgDmg} $**: Average damage dealt by the ability (computed using dice).
# - **$ \text{EffScore} $**: The total effect score, considering both the effect’s strength and duration.
# - **$ \text{CDPenalty} $**: A cooldown penalty based on the cooldown duration.
# - **$ \text{AoEArea} $**: The area of effect based on the type and range of the ability.
# - **$ r_i $**: The rating (or strength) of an individual effect $ i $ based on a scale from 1 to 5.
# - **$ d_i $**: The duration of effect $ i $ in rounds (default of 1 if not specified).
#
# #### Formulas:
#
# 1. **Average Damage**
#
#    $$ \text{AvgDamage} = (\text{dice count} * (\text{dice sites} + 1) / 2) + \text{bonus} $$
#
# 2. **Effect Score**:
#
# **General calculation**
#    $$
#    \text{EffScore} = \sum_{i} r_i \times d_i
#    $$
#
#    where:
#    - $ r_i $ is the strength rating of effect $ i $.
#    - $ d_i $ is the duration of effect $ i $ in rounds.
#
# **Cases**
#   - Heal: healing rating * (average of healing dices)^1/2
#   - Effects with range: effect rating * (value in feet/5)^1/2
#   - Default: effect rating * duration or level
#
# <br>
#
# 3. **Area of Effect (AoE) Calculation**:
#
#    The calculation varies based on the type of AoE and is based on tiles (5x5):
#    - For "radius" attacks (circular area):
#      $$
#      \text{AoEArea} = 2 * range^2 + 2 * range
#      $$
#    - For "cone" attacks:
#      $$
#      \text{AoEArea} = range^2
#      $$
#    - For "line" attacks (assuming a width of 5 feet):
#      $$
#      \text{AoEArea} = \text{range} \times 5
#      $$
#    - For "self" or "single" attacks:
#      $$
#      \text{AoEArea} = 1
#      $$
#
# <br>
#
# 4. **Final Strength Metric**:
#
#    $$
#    \text{Strength Metric} = \left(\text{AvgDmg} + \text{EffScore}\right) \times \sqrt{\text{AoEArea}}
#    $$

# %%
import numpy as np
import re
from utils import parse_dice, parse_dice_average, calculate_aoe_area, combined_damage_statistics

# Step 2: Ability Rating
action_df = dataframes["actions"]


#Calculate effect score based on ratings and parameter
def get_multiplier(parameter):
    if isinstance(parameter, (int, float)):
        print(f"parameter {parameter} is an integer")
        return parameter
    elif isinstance(parameter, str):
        duration = parameter.strip()
        match duration:
            case d if d.endswith('r'):
                return int(d.rstrip('r'))
            case d if d.startswith('lv'):
                return int(d.lstrip('lv'))
            case "until freed":
                return 1  # Special case
            case d if re.fullmatch(r'\d+d\d+([+-]\d+)?', d):
                return parse_dice_average(d)
            case d if d.endswith('ft'):
                return int(d.rstrip('ft'))
            case _:
                return 1  # Default multiplier if parsing fails
    else:
        return 1  # Default multiplier


def calculate_effect_value(effect_name, rating, parameter):
    """Calculates the effect value based on effect name, rating, and duration."""
    multiplier = get_multiplier(parameter)
    match effect_name:
        case "heal":
            adjusted_multiplier = round(multiplier ** 0.5)
            effect_value = rating * adjusted_multiplier
            print(
                f"Calculating 'heal' effect: rating {rating} * average heal {multiplier} = {effect_value}")
            return effect_value
        case _:
            # Default calculation
            # for effects with range
            if parameter.endswith('ft'):
                adjusted_multiplier = round((multiplier / 5) ** 0.5)
                effect_value = rating * adjusted_multiplier
                print(
                    f"Calculating default effect '{effect_name}': rating {rating} * root of distance {adjusted_multiplier} = {effect_value}")
            # for the rest
            else:
                effect_value = rating * multiplier
                print(
                    f"Calculating default effect '{effect_name}': rating {rating} * multiplier {multiplier} = {effect_value}")
            return effect_value


def calculate_effect_score(effects):
    effect_score = 0
    for effect in effects:
        effect_name = effect[0]
        duration = effect[1] if len(effect) > 1 else 1
        rating = effect_data.get(effect_name, 0)  # Default to 0 if the effect is not found
        effect_value = calculate_effect_value(effect_name, rating, duration)
        effect_score += effect_value
    return effect_score


# Calculate a final metric based on all factors
def calculate_strength_metric(row):
    damages = row['damage']
    min_dmg, max_dmg, avg_dmg, std_dmg = combined_damage_statistics(damages)
    damage_score = avg_dmg
    effect_score = calculate_effect_score(row['effects'])
    aoe_area = calculate_aoe_area(row['aoe'], row['range'])
    strength_metric = round(damage_score + effect_score + (aoe_area ** 0.5))
    return strength_metric, max_dmg, avg_dmg


output_series = action_df.apply(calculate_strength_metric, axis=1)
strength_metrics, max_damages, avg_damages = zip(*output_series)
action_df['strength_metric'] = strength_metrics
action_df['max_dmg'] = max_damages
action_df['avg_dmg'] = avg_damages

action_df
# Out:
# Calculating default effect 'exhausted': rating 5 * multiplier 4 = 20
# Calculating default effect 'prone': rating 3 * multiplier 1 = 3
# Calculating default effect 'blinded': rating 3 * multiplier 1 = 3
# Calculating default effect 'paralysed': rating 5 * multiplier 2 = 10
# Calculating default effect 'paralysed': rating 5 * multiplier 1 = 5
# Calculating default effect 'bleeding': rating 5 * multiplier 1 = 5
# Calculating default effect 'bleeding': rating 5 * multiplier 2 = 10
# Calculating default effect 'bleeding': rating 5 * multiplier 2 = 10
# Calculating default effect 'deaf': rating 0 * multiplier 1 = 0
# Calculating default effect 'leap': rating 2 * multiplier 1 = 2
# Calculating default effect 'petrified': rating 5 * multiplier 1 = 5
# Calculating default effect 'grappled': rating 3 * multiplier 1 = 3
# Calculating default effect 'restrained': rating 4 * multiplier 2 = 8
# Calculating default effect 'difficult_terrain': rating 2 * multiplier 20 = 40
# Calculating default effect 'resistance_(all)': rating 4 * multiplier 1 = 4
# Calculating 'heal' effect: rating 2 * average heal 9.0 = 6
# Calculating default effect 'bleeding': rating 5 * multiplier 1 = 5
# Calculating default effect 'disadvantage_(hit)': rating 4 * multiplier 1 = 4
# Calculating default effect 'petrified': rating 5 * multiplier 1 = 5
# Calculating default effect 'escape': rating 3 * root of distance 2 = 6
# Calculating default effect 'knockback': rating 3 * root of distance 2 = 6
# Calculating default effect 'knockback': rating 3 * root of distance 1 = 3
# Calculating default effect 'disadvantage_(hit)': rating 4 * multiplier 1 = 4
# Calculating default effect 'petrified': rating 5 * multiplier 2 = 10
# Calculating 'heal' effect: rating 2 * average heal 9.0 = 6
# Calculating default effect 'stunned': rating 4 * multiplier 1 = 4
# Calculating default effect 'disadvantage_(hit)': rating 4 * multiplier 1 = 4
# Calculating default effect 'stunned': rating 4 * multiplier 1 = 4
# Calculating default effect 'poisoned': rating 3 * multiplier 2 = 6
# Calculating default effect 'invisible': rating 4 * multiplier 10 = 40
# Calculating default effect 'double_damage': rating 4 * multiplier 2 = 8
# Calculating default effect 'disadvantage_(hit)': rating 4 * multiplier 2 = 8
# Calculating default effect 'disadvantage_(dmg)': rating 4 * multiplier 2 = 8
# Calculating default effect 'petrified': rating 5 * multiplier 2 = 10
# Calculating default effect 'stunned': rating 4 * multiplier 1 = 4
# Calculating default effect 'pulled': rating 0 * multiplier 1 = 0
# Calculating default effect 'restrained': rating 4 * multiplier 1 = 4
# Calculating default effect 'grappled': rating 3 * multiplier 1 = 3
# Calculating default effect 'poisoned': rating 3 * multiplier 4 = 12
# Calculating default effect 'stunned': rating 4 * multiplier 1 = 4
# Calculating default effect 'poisoned': rating 3 * multiplier 3 = 9
# Calculating default effect 'prone': rating 3 * multiplier 2 = 6
# Calculating default effect 'exhausted': rating 5 * multiplier 1 = 5
# Calculating default effect 'disadvantage_(hit)': rating 4 * multiplier 1 = 4
# Calculating default effect 'double_damage': rating 4 * multiplier 1 = 4
# Calculating default effect 'poisoned': rating 3 * multiplier 2 = 6
# Calculating 'heal' effect: rating 2 * average heal 19.5 = 8
# Calculating default effect 'bleeding': rating 5 * multiplier 2 = 10
# Calculating default effect 'prone': rating 3 * multiplier 2 = 6
# Calculating default effect 'leap': rating 2 * multiplier 1 = 2
# Calculating default effect 'difficult_terrain': rating 2 * multiplier 1 = 2
# Calculating default effect 'leap': rating 2 * multiplier 1 = 2
# Calculating default effect 'increased_movement': rating 3 * multiplier 1 = 3
# Calculating default effect 'disadvantage_(hit)': rating 4 * multiplier 1 = 4
# Calculating default effect 'stunned': rating 4 * multiplier 2 = 8
# Calculating default effect 'frightened': rating 3 * multiplier 3 = 9
# Calculating default effect 'poisoned': rating 3 * multiplier 2 = 6
# Calculating default effect 'knockback': rating 3 * root of distance 2 = 6
# Calculating default effect 'paralysed': rating 5 * multiplier 3 = 15
# Calculating default effect 'restrained': rating 4 * multiplier 1 = 4
# Calculating default effect 'knockback': rating 3 * root of distance 2 = 6
# Calculating default effect 'blinded': rating 3 * multiplier 1 = 3
# Calculating default effect 'restrained': rating 4 * multiplier 1 = 4
# Calculating default effect 'paralysed': rating 5 * multiplier 1 = 5
# Calculating default effect 'pull': rating 2 * root of distance 3 = 6
# Calculating default effect 'knockback': rating 3 * root of distance 1 = 3
# Calculating default effect 'restrained': rating 4 * multiplier 1 = 4
# Calculating default effect 'grappled': rating 3 * multiplier 1 = 3
# Calculating default effect 'restrained': rating 4 * multiplier 1 = 4
# Calculating default effect 'paralysed': rating 5 * multiplier 1 = 5
#                     name  legendary cooldown range     aoe  hitbonus  \
# 0   Abyssaler Nebelhauch      False   [3, r]    70  radius         0
# 1         Berserkersturm      False   [1, d]    40    line         9
# 2           Blendgranate      False   [1, d]    30  radius         0
# 3    Blitz aus der Tiefe      False   [3, r]   100  single         0
# 4            Blitzschlag      False   [6, r]    60    cone         8
# ..                   ...        ...      ...   ...     ...       ...
# 90           Windschnitt      False   [1, d]    30    cone         0
# 91           Wurzelgriff      False       []    10    cone         6
# 92            Würgegriff      False       []     5  single         0
# 93          Zerquetschen      False       []     5  single         8
# 94            Überladung      False   [1, d]    20  radius         0
#
#       savereq                   damage             effects  strength_metric  \
# 0   [con, 19]           [[12d6, acid]]  [[exhausted, lv4]]               82
# 1          []      [[3d8+6, slashing]]       [[prone, 1r]]               25
# 2   [con, 16]                       []     [[blinded, 1r]]               12
# 3   [dex, 18]      [[2d10, lightning]]   [[paralysed, 2r]]               22
# 4          []      [[8d12, lightning]]   [[paralysed, 1r]]               69
# ..        ...                      ...                 ...              ...
# 90  [dex, 19]      [[5d8+2, slashing]]                  []               30
# 91         []   [[1d8+4, bludgeoning]]   [[restrained, 1]]               14
# 92  [str, 17]     [[2d8, bludgeoning]]    [[grappled, 1r]]               13
# 93         []  [[2d10+6, bludgeoning]]  [[restrained, 1r]]               22
# 94  [con, 17]       [[5d8, lightning]]    [[paralysed, 2]]               34
#
#     max_dmg  avg_dmg
# 0        72     42.0
# 1        30     19.5
# 2         0      0.0
# 3        20     11.0
# 4        96     52.0
# ..      ...      ...
# 90       42     24.5
# 91       12      8.5
# 92       16      9.0
# 93       26     17.0
# 94       40     22.5
#
# [95 rows x 12 columns]

# %% [markdown]
# ### Effect Value Calculation
#
# Calculate the **effect value** based on the **effect name**:
#
# 1. **For 'heal':**
#
#    $$
#    \text{effect\_value} = \text{rating}(\text{'heal'}) + \text{average dice roll}
#    $$
#
# 2. **For 'grappled':**
#
#    - **If duration is 'until freed':**
#
#      $$
#      \text{effect\_value} = \text{rating}(\text{'grappled'}) \times 2
#      $$
#
#    - **Else:**
#
#      $$
#      \text{effect\_value} = \text{rating}(\text{'grappled'}) \times \text{duration}
#      $$
#
# 3. **For other effects:**
#
#    - **If duration ends with 'ft':**
#
#      $$
#      \text{effect\_value} = \text{rating}(\text{effect\_name}) + \frac{\text{distance}}{5}
#      $$
#
#      (Adds distance in tiles to the rating)
#
#    - **Else:**
#
#      $$
#      \text{effect\_value} = \text{rating}(\text{effect\_name}) \times \text{duration or level}
#      $$

# %%
# Step 3: calculate strength of enemy without the actions
enemies_df = dataframes["enemies"]


def calculate_movement_metric(movement):
    movement_multipliers = {
        'laufend': 1.0,
        'schwimmend': 1.0,
        'fliegend': 1.0,
        'schwebend': 1.0,
        'hüpfend': 1.0,
        'rutschend': 1.0
    }
    movement_metric = 0
    if movement is None:
        return 0
    for move in movement:
        move_type, move_distance = move.split()
        move_distance = int(move_distance) / 5
        if move_type not in movement_multipliers:
            print(f"movement type {move_type} is currently not supported and set to 1")
            multiplier = 1.0
        else:
            multiplier = movement_multipliers.get(move_type.lower())
        movement_metric += move_distance * multiplier

    return movement_metric


def calculate_weaknesses_metric(weaknesses):
    weaknesses_metric = len(weaknesses)
    return weaknesses_metric


def calculate_resistances_metric(resistances):
    resistances_metric = len(resistances)
    return resistances_metric


def calculate_immunities_metric(immunities):
    immunities_metric = len(immunities)
    return immunities_metric


def calculate_ability_scores_metric(ability_scores):
    ability_scores_metric = sum(ability_scores)
    return ability_scores_metric


def calculate_tank_metric(hp, ac):
    tank_metric = hp * ac / 100
    return tank_metric


def calculate_enemy_no_action_metric(row):
    tank_metric = calculate_tank_metric(row['hp'], row['ac'])
    movement_metric = calculate_movement_metric(row['movement'])
    weaknesses_metric = calculate_weaknesses_metric(row['weaknesses'])
    resistances_metric = calculate_resistances_metric(row['resistances'])
    immunities_metric = calculate_immunities_metric(row['immunities'])
    ability_scores = row[['str', 'dex', 'con', 'int', 'wis', 'cha']].values.tolist()
    ability_scores_metric = calculate_ability_scores_metric(ability_scores)

    no_action_metric = tank_metric + movement_metric - weaknesses_metric + resistances_metric + 2 * immunities_metric + ability_scores_metric
    return no_action_metric


enemies_df['no_action_metric'] = enemies_df.apply(calculate_enemy_no_action_metric, axis=1)
enemies_df
# Out:
# movement type kriechend is currently not supported and set to 1
# movement type kletternd is currently not supported and set to 1
# movement type grabend is currently not supported and set to 1
# movement type krabbelnd is currently not supported and set to 1
# movement type springend is currently not supported and set to 1
# movement type krabbelnd is currently not supported and set to 1
#                  name   boss                   bosstitle             type  \
# 0       Abwassernager  False                                   Ungeziefer
# 1             Abyssor   True  Peiniger des Meerestempels     Monstrosität
# 2           Aerocacti  False                                      Pflanze
# 3            Arachnia  False                                       Bestie
# 4              Babasu  False                              Abscheulichkeit
# 5     Bandagenwandler  False                                        Untot
# 6              Bandit  False                                     Humanoid
# 7      Bestienkrieger  False                                 Monstrosität
# 8        Blitzschneck  False                                       Bestie
# 9     Blutstahlritter  False                                        Untot
# 10       Bohrschnabel  False                                       Bestie
# 11           Boreanos   True    Peiniger der Schneelande            Untot
# 12    Drachenmäulchen  False                                      Pflanze
# 13           Drösling  False                                 Monstrosität
# 14  Dämonenabkömmling  False                                        Dämon
# 15         Eiseskälte  False                                    Elementar
# 16         Eisflügler  False                                       Bestie
# 17           Eisgeist  False                                        Untot
# 18        Elektrabrax   True    Peiniger des Blitzaltars     Monstrosität
# 19          Erzknecht  False                                        Untot
# 20     Fingerkrabller  False                                 Monstrosität
# 21        Flammengrün  False                                      Pflanze
# 22      Gezeitenblick  False                                 Monstrosität
# 23             Goblin  False                                     Humanoid
# 24        Klinguschel  False                                 Monstrosität
# 25            Krokuin  False                                       Bestie
# 26   Meeresschlächter  False                                 Monstrosität
# 27             Octark  False                                 Monstrosität
# 28      Riesenflügler  False                                       Bestie
# 29             Ritter  False                                     Humanoid
# 30       Stahlschuppe  False                                     Humanoid
# 31          Tetravora   True                                      Pflanze
# 32          Voltfaden  False                                    Elementar
# 33      Zunderflügler  False                                       Bestie
#
#      hp  ac                       movement  str  dex  con  int  wis  cha  \
# 0    30  15    [laufend 40, schwimmend 30]    0    3    2   -3   -2   -1
# 1   400  20               [schwimmend 100]    7    2    6    2    3    4
# 2    40  16                  [fliegend 25]    1    2    1    2    2    5
# 3    40  18                   [laufend 50]    3    6    4    1    2   -4
# 4    55  16                 [schwebend 30]    1    3    2    5    4    6
# 5    70  18                   [laufend 10]    6   -3    6   -1    2   -3
# 6    80  17                   [laufend 40]    2    3    1    0    1    0
# 7   100  18                   [laufend 30]    6    1    5   -2    2   -1
# 8    80  16   [kriechend 10, kletternd 10]    2   -4    4    2    3    1
# 9   200  20                   [laufend 20]    6    1    5    1    2    3
# 10   30  13      [fliegend 50, laufend 10]    1    4    1    2    3    0
# 11  225  19                 [schwebend 80]    5    2    4    1    3    4
# 12   65  17                   [hüpfend 35]    4    3    1    2    1    4
# 13   65  17                  [fliegend 40]   -2    2    1    0    2    0
# 14  160  18                   [laufend 30]    5    3    4    1    2    3
# 15   90  15                 [rutschend 10]    4   -1    5   -3    1   -2
# 16   20  13                  [fliegend 60]   -2    4    1   -3    1   -2
# 17  130  17                 [schwebend 40]    3    3    4    2    3    5
# 18  500  20       [laufend 50, grabend 70]    6    1    5    2    3    0
# 19   30  13                   [laufend 20]    2    1    1    0    0    0
# 20   95  17                 [krabbelnd 30]    4    3    3    4    3    4
# 21   70  14                             []    4   -2    5   -3    1   -2
# 22  120  17    [laufend 40, schwimmend 50]    4    1    4    3    2    5
# 23   20  13                   [laufend 30]    1    2    1   -1    0   -1
# 24   80  20                 [springend 10]    5    1    5   -3   -2   -2
# 25   60  16  [rutschend 50, schwimmend 60]    3    3    2    1    1    1
# 26   90  18    [laufend 30, schwimmend 40]    4    2    3   -1    2    1
# 27   80  17   [krabbelnd 5, schwimmend 50]    4    2    3   -1    3   -2
# 28  140  16                  [fliegend 80]    5    4    4    1    3    2
# 29  180  18                   [laufend 30]    5    2    4    1    3    5
# 30   90  17                   [laufend 30]    3    4    2    1    1    2
# 31  400  18                             []    4    4    4    4    4    4
# 32  140  16                 [schwebend 40]    3    2    4    1    3    1
# 33   20  13                  [fliegend 60]   -2    4    1   -3    1   -2
#
#                       weaknesses                              resistances  \
# 0                        [Feuer]                                  [Säure]
# 1                        [Blitz]         [Nicht-magischer Schaden, Kälte]
# 2   [Feuer, Schnitt, Necrotisch]                                  [Stich]
# 3                 [Feuer, Blitz]                                  [Stich]
# 4                [Heilige Magie]                                       []
# 5         [Heilige Magie, Feuer]                                [Schnitt]
# 6                             []                                       []
# 7                        [Feuer]                [Nicht-magischer Schaden]
# 8                        [Kälte]                [Nicht-magischer Schaden]
# 9                [Heilige Magie]                [Nicht-magischer Schaden]
# 10                       [Blitz]                                       []
# 11                       [Feuer]                                       []
# 12   [Feuer, Gift, Säure, Kälte]                                  [Blitz]
# 13                       [Kälte]                                       []
# 14               [Heilige Magie]  [Feuer, Kälte, Nicht-magischer Schaden]
# 15               [Feuer, Stumpf]                            [Hieb, Stich]
# 16                       [Feuer]                                       []
# 17        [Feuer, Heilige Magie]         [Kälte, Nicht-magischer Schaden]
# 18               [Stumpf, Blitz]                           [Feuer, Kälte]
# 19        [Heilige Magie, Blitz]                                  [Stich]
# 20                            []     [Nicht-magischer Schaden, Psychisch]
# 21                       [Kälte]                   [Feuer, Stumpf, Stich]
# 22                       [Blitz]                [Kälte, Feuer, Psychisch]
# 23                            []                                       []
# 24                 [Blitz, Hieb]                                       []
# 25                [Kälte, Blitz]                                   [Gift]
# 26                       [Kälte]                                  [Feuer]
# 27                [Kälte, Blitz]                                  [Feuer]
# 28                       [Blitz]                                       []
# 29                            []                [Nicht-magischer Schaden]
# 30                       [Blitz]                                   [Gift]
# 31                       [Feuer]                                       []
# 32                       [Kälte]                               [Piercing]
# 33                       [Kälte]                                       []
#
#                                            immunities  \
# 0                                   [Gift, Krankheit]
# 1   [Gift, Betäubt, Erschöpft, Bezaubert, Gepackt,...
# 2                                       [Gift, Säure]
# 3                                       [Gift, Säure]
# 4                           [Nicht-magischer Schaden]
# 5                                       [Gift, Säure]
# 6                                                  []
# 7                                       [Verängstigt]
# 8                                       [Blitz, Gift]
# 9                     [Gift, Nekrotisch, Verängstigt]
# 10                                                 []
# 11  [Kälte, Gift, Psychisch, Betäubt, Erschöpft, B...
# 12                                      [Taub, Blind]
# 13                                                 []
# 14                           [Verängstigt, Erschöpft]
# 15                           [Kälte, Erschöpft, Gift]
# 16                                            [Kälte]
# 17            [Verängstigt, Gift, Erschöpft, Betäubt]
# 18                         [Gift, Betäubt, Erschöpft]
# 19                                             [Gift]
# 20            [Verängstigt, Betäubt, Erschöpft, Gift]
# 21                         [Gift, Erschöpft, Betäubt]
# 22                         [Gift, Erschöpft, Betäubt]
# 23                                                 []
# 24          [Stich, Stumpf, Gift, Betäubt, Erschöpft]
# 25                                                 []
# 26                                             [Gift]
# 27                                    [Gift, Betäubt]
# 28                               [Erschöpft, Betäubt]
# 29                                      [Verängstigt]
# 30                                        [Erschöpft]
# 31  [Gift, Betäubt, Erschöpft, Bezaubert, Gepackt,...
# 32                                      [Blitz, Gift]
# 33                                            [Feuer]
#
#                                               actions  no_action_metric
# 0                             [Rattenbiss, Pestwolke]             21.50
# 1   [Reißzahnbiss, Schädelbrumme, Abyssaler Nebelh...            137.00
# 2                       [Stachelschuss, Stachelwalze]             26.40
# 3               [Würgegriff, Netzschuss, Säurespeier]             32.20
# 4                            [Spektraler Biss, Fluch]             36.80
# 5                           [Würgegriff, Klingenhieb]             24.60
# 6   [Schurkischer Angriff, Schneller Hieb, Blendgr...             28.60
# 7   [Klingenhieb, Brutale Hiebe, Zerquetschen, Ber...             37.00
# 8   [Elektrisierender Stoß, Blitzstrahl, Überladun...             28.80
# 9          [Blutiger Schlag, Blutige Rache, Blutwoge]             68.00
# 10               [Bohrschnabel, Kreischen, Sturzflug]             25.90
# 11  [Geistergeweih, Kältestrahl, Frostige Hufe, Ei...             88.75
# 12  [Schädelbrumme, Schnapper, Regeneration, Giftz...             34.05
# 13                         [Schädelbrumme, Quälgeist]             21.05
# 14  [Dämonischer Hieb, Schwarze Welle, Schattenbar...             58.80
# 15                          [Frostiger Nebelschleier]             25.50
# 16  [Frostiger Vampirbiss, Frostiger Flügelschlag,...             14.60
# 17   [Spektrale Klinge, Eisiger Sturm, Eisige Ketten]             58.10
# 18  [Greifzangen, Steinsalve, Donnernde Explosion,...            147.00
# 19               [Klingenhieb, Fluch, Schneller Hieb]             12.90
# 20  [Schmetternde Faust, Gedankenpein, Telekinetis...             53.15
# 21  [Feuerballwurf, Wurzelgriff, Verschlingen, Fla...             20.80
# 22  [Wasserpeitsche, Gedankenpein, Flutwelle, Geis...             65.40
# 23                  [Knüppelschlag, Rabiater Angriff]             10.60
# 24  [Klingenklatscher, Dornenstoß, Schalenramme, E...             30.00
# 25                      [Bohrschnabel, Reptilienbiss]             41.60
# 26  [Klingenhieb, Schwanzschlag, Wasserstrahl, Str...             43.20
# 27  [Tentakelpeitsche, Würgegriff, Tintenwolke, Wa...             36.60
# 28  [Sturzflug, Kreischen, Giftzahn, Kratzer, Stür...             60.40
# 29  [Kurzschwertschlag, Großschwerthieb, Lanzensto...             61.40
# 30  [Brutale Hiebe, Beilhieb, Schwanzschlag, Schne...             36.30
# 31  [Reißzahnbiss, Schädelbrumme, Quadro-Giftspore...            107.00
# 32  [Blitzstrahl, Elektrisierender Stoß, Tentakelp...             48.40
# 33  [Feuriger Vampirbiss, Flammender Flügelschlag,...             14.60

# %%
from typing import Tuple, List


# Step 4: combine action-metric and enemy-metric to create danger level of an enemy
def calculate_max_action_potential(actions):
    # Get details for actions per enemy
    detailed_actions: List[Tuple[
        int, int, int, int]] = []  # contains list of tuple like this: [strength_metric,cooldown,max_dmg,avg_dmg]
    for action in actions:
        if action not in action_df["name"].values:
            print(f"{action} is not in action df")
            continue
        detailed_action_row = action_df[action_df["name"] == action]
        strength_metric = detailed_action_row["strength_metric"].iloc[0]
        cooldown = detailed_action_row["cooldown"].iloc[0]
        # if the cooldown duration type is not rounds (for example days) don't use the action for max action strength calculation
        if len(cooldown) == 2 and cooldown[1] == 'd':
            cooldown_round_duration = 10
        else:
            cooldown_round_duration = int(cooldown[0]) if len(cooldown) == 2 else 0
        max_dmg = detailed_action_row["max_dmg"].iloc[0]
        avg_dmg = detailed_action_row["avg_dmg"].iloc[0]
        detailed_actions.append((strength_metric, cooldown_round_duration, max_dmg, avg_dmg))

    # Calculate max action potential by using averages for enemies with actions that have cooldown and fill the cooldown time with the second-best option
    # Sort actions by strength_metric in descending order
    # detailed_actions = [(500,5,1,1),(400,2,1,1),(300,4,1,1),(100,0,1,1)]
    detailed_actions.sort(key=lambda x: x[0], reverse=True)
    strongest_action_cooldown_end = 0
    action_strength_sum = 0
    rounds = 0
    usable_actions = detailed_actions.copy()
    cooldown_list = []  # these are the actions that are on cooldown
    # tuple in usable_actions and cooldown_list list is build like this: [strength_metric,cooldown,max_dmg,avg_dmg]
    while True:
        # if the strongest action has no cooldown just stop after adding its strength else stop after the cooldown of the strongest action is up
        if strongest_action_cooldown_end < rounds:
            max_action_potential = action_strength_sum / rounds
            break

        # insert the weakest of the cooldown actions first at the beginning of the usable_list and after that the strongest, so the strongest is always the first element of the list
        cooldown_list.sort(key=lambda x: x[0], reverse=False)
        loop_postion = 0
        for strength_metric, cooldown, max_dmg, avg_dmg, on_cooldown_until in cooldown_list:
            if on_cooldown_until < rounds:
                usable_actions.insert(0, (strength_metric, cooldown, max_dmg, avg_dmg))
                del cooldown_list[loop_postion]
            else:
                loop_postion = + 1
        # if there are no actions left without a cooldown, then do nothing as an action if the rest is on cooldown        
        if len(usable_actions) == 0:
            usable_actions.insert(0, 0, 0, 0)
        current_action_strength_metric = usable_actions[0][0]
        current_action_cooldown = usable_actions[0][1]
        current_action_max_dmg = usable_actions[0][2]
        current_action_avg_dmg = usable_actions[0][3]
        on_cooldown_until = current_action_cooldown + rounds

        action_strength_sum += current_action_strength_metric
        # if the current action has cooldown add it to the cooldown_list and delete it from the usable_action list
        if current_action_cooldown != 0:
            if strongest_action_cooldown_end == 0:
                strongest_action_cooldown_end = on_cooldown_until
            cooldown_list.append((current_action_strength_metric, current_action_cooldown,
                                  current_action_max_dmg, current_action_avg_dmg,
                                  on_cooldown_until))
            usable_actions = usable_actions[1:]
        rounds += 1

    # 0 + 3 = 3 (1,2,2,2,3) <- so after round 3 action number 2 is usable again (we start with round 0)
    return max_action_potential


def calculate_enemy_combined_metric(row):
    max_action_potential = calculate_max_action_potential(row["actions"])
    difficulty_rating = row["no_action_metric"] + max_action_potential
    return difficulty_rating


enemies_df['difficulty_rating'] = round(enemies_df.apply(calculate_enemy_combined_metric, axis=1),
                                        2)
enemies_df
# action potential = stärkste Action, wenn Action cooldown hat Action hinzufügen, dann auffüllen der danach stärksten Action bis cooldown erfüllt ist, dann average berechnen. Nuke(metric= 300, cooldown = 3r), Hieb(metric=100, cooldown=0r) -> action_potential = (300 + 100 + 100 + 100) / 4
# Out:
# Schattenbarriere is not in action df
# Elektrischer Stoß is not in action df
# Beilhieb is not in action df
#                  name   boss                   bosstitle             type  \
# 0       Abwassernager  False                                   Ungeziefer
# 1             Abyssor   True  Peiniger des Meerestempels     Monstrosität
# 2           Aerocacti  False                                      Pflanze
# 3            Arachnia  False                                       Bestie
# 4              Babasu  False                              Abscheulichkeit
# 5     Bandagenwandler  False                                        Untot
# 6              Bandit  False                                     Humanoid
# 7      Bestienkrieger  False                                 Monstrosität
# 8        Blitzschneck  False                                       Bestie
# 9     Blutstahlritter  False                                        Untot
# 10       Bohrschnabel  False                                       Bestie
# 11           Boreanos   True    Peiniger der Schneelande            Untot
# 12    Drachenmäulchen  False                                      Pflanze
# 13           Drösling  False                                 Monstrosität
# 14  Dämonenabkömmling  False                                        Dämon
# 15         Eiseskälte  False                                    Elementar
# 16         Eisflügler  False                                       Bestie
# 17           Eisgeist  False                                        Untot
# 18        Elektrabrax   True    Peiniger des Blitzaltars     Monstrosität
# 19          Erzknecht  False                                        Untot
# 20     Fingerkrabller  False                                 Monstrosität
# 21        Flammengrün  False                                      Pflanze
# 22      Gezeitenblick  False                                 Monstrosität
# 23             Goblin  False                                     Humanoid
# 24        Klinguschel  False                                 Monstrosität
# 25            Krokuin  False                                       Bestie
# 26   Meeresschlächter  False                                 Monstrosität
# 27             Octark  False                                 Monstrosität
# 28      Riesenflügler  False                                       Bestie
# 29             Ritter  False                                     Humanoid
# 30       Stahlschuppe  False                                     Humanoid
# 31          Tetravora   True                                      Pflanze
# 32          Voltfaden  False                                    Elementar
# 33      Zunderflügler  False                                       Bestie
#
#      hp  ac                       movement  str  dex  con  int  wis  cha  \
# 0    30  15    [laufend 40, schwimmend 30]    0    3    2   -3   -2   -1
# 1   400  20               [schwimmend 100]    7    2    6    2    3    4
# 2    40  16                  [fliegend 25]    1    2    1    2    2    5
# 3    40  18                   [laufend 50]    3    6    4    1    2   -4
# 4    55  16                 [schwebend 30]    1    3    2    5    4    6
# 5    70  18                   [laufend 10]    6   -3    6   -1    2   -3
# 6    80  17                   [laufend 40]    2    3    1    0    1    0
# 7   100  18                   [laufend 30]    6    1    5   -2    2   -1
# 8    80  16   [kriechend 10, kletternd 10]    2   -4    4    2    3    1
# 9   200  20                   [laufend 20]    6    1    5    1    2    3
# 10   30  13      [fliegend 50, laufend 10]    1    4    1    2    3    0
# 11  225  19                 [schwebend 80]    5    2    4    1    3    4
# 12   65  17                   [hüpfend 35]    4    3    1    2    1    4
# 13   65  17                  [fliegend 40]   -2    2    1    0    2    0
# 14  160  18                   [laufend 30]    5    3    4    1    2    3
# 15   90  15                 [rutschend 10]    4   -1    5   -3    1   -2
# 16   20  13                  [fliegend 60]   -2    4    1   -3    1   -2
# 17  130  17                 [schwebend 40]    3    3    4    2    3    5
# 18  500  20       [laufend 50, grabend 70]    6    1    5    2    3    0
# 19   30  13                   [laufend 20]    2    1    1    0    0    0
# 20   95  17                 [krabbelnd 30]    4    3    3    4    3    4
# 21   70  14                             []    4   -2    5   -3    1   -2
# 22  120  17    [laufend 40, schwimmend 50]    4    1    4    3    2    5
# 23   20  13                   [laufend 30]    1    2    1   -1    0   -1
# 24   80  20                 [springend 10]    5    1    5   -3   -2   -2
# 25   60  16  [rutschend 50, schwimmend 60]    3    3    2    1    1    1
# 26   90  18    [laufend 30, schwimmend 40]    4    2    3   -1    2    1
# 27   80  17   [krabbelnd 5, schwimmend 50]    4    2    3   -1    3   -2
# 28  140  16                  [fliegend 80]    5    4    4    1    3    2
# 29  180  18                   [laufend 30]    5    2    4    1    3    5
# 30   90  17                   [laufend 30]    3    4    2    1    1    2
# 31  400  18                             []    4    4    4    4    4    4
# 32  140  16                 [schwebend 40]    3    2    4    1    3    1
# 33   20  13                  [fliegend 60]   -2    4    1   -3    1   -2
#
#                       weaknesses                              resistances  \
# 0                        [Feuer]                                  [Säure]
# 1                        [Blitz]         [Nicht-magischer Schaden, Kälte]
# 2   [Feuer, Schnitt, Necrotisch]                                  [Stich]
# 3                 [Feuer, Blitz]                                  [Stich]
# 4                [Heilige Magie]                                       []
# 5         [Heilige Magie, Feuer]                                [Schnitt]
# 6                             []                                       []
# 7                        [Feuer]                [Nicht-magischer Schaden]
# 8                        [Kälte]                [Nicht-magischer Schaden]
# 9                [Heilige Magie]                [Nicht-magischer Schaden]
# 10                       [Blitz]                                       []
# 11                       [Feuer]                                       []
# 12   [Feuer, Gift, Säure, Kälte]                                  [Blitz]
# 13                       [Kälte]                                       []
# 14               [Heilige Magie]  [Feuer, Kälte, Nicht-magischer Schaden]
# 15               [Feuer, Stumpf]                            [Hieb, Stich]
# 16                       [Feuer]                                       []
# 17        [Feuer, Heilige Magie]         [Kälte, Nicht-magischer Schaden]
# 18               [Stumpf, Blitz]                           [Feuer, Kälte]
# 19        [Heilige Magie, Blitz]                                  [Stich]
# 20                            []     [Nicht-magischer Schaden, Psychisch]
# 21                       [Kälte]                   [Feuer, Stumpf, Stich]
# 22                       [Blitz]                [Kälte, Feuer, Psychisch]
# 23                            []                                       []
# 24                 [Blitz, Hieb]                                       []
# 25                [Kälte, Blitz]                                   [Gift]
# 26                       [Kälte]                                  [Feuer]
# 27                [Kälte, Blitz]                                  [Feuer]
# 28                       [Blitz]                                       []
# 29                            []                [Nicht-magischer Schaden]
# 30                       [Blitz]                                   [Gift]
# 31                       [Feuer]                                       []
# 32                       [Kälte]                               [Piercing]
# 33                       [Kälte]                                       []
#
#                                            immunities  \
# 0                                   [Gift, Krankheit]
# 1   [Gift, Betäubt, Erschöpft, Bezaubert, Gepackt,...
# 2                                       [Gift, Säure]
# 3                                       [Gift, Säure]
# 4                           [Nicht-magischer Schaden]
# 5                                       [Gift, Säure]
# 6                                                  []
# 7                                       [Verängstigt]
# 8                                       [Blitz, Gift]
# 9                     [Gift, Nekrotisch, Verängstigt]
# 10                                                 []
# 11  [Kälte, Gift, Psychisch, Betäubt, Erschöpft, B...
# 12                                      [Taub, Blind]
# 13                                                 []
# 14                           [Verängstigt, Erschöpft]
# 15                           [Kälte, Erschöpft, Gift]
# 16                                            [Kälte]
# 17            [Verängstigt, Gift, Erschöpft, Betäubt]
# 18                         [Gift, Betäubt, Erschöpft]
# 19                                             [Gift]
# 20            [Verängstigt, Betäubt, Erschöpft, Gift]
# 21                         [Gift, Erschöpft, Betäubt]
# 22                         [Gift, Erschöpft, Betäubt]
# 23                                                 []
# 24          [Stich, Stumpf, Gift, Betäubt, Erschöpft]
# 25                                                 []
# 26                                             [Gift]
# 27                                    [Gift, Betäubt]
# 28                               [Erschöpft, Betäubt]
# 29                                      [Verängstigt]
# 30                                        [Erschöpft]
# 31  [Gift, Betäubt, Erschöpft, Bezaubert, Gepackt,...
# 32                                      [Blitz, Gift]
# 33                                            [Feuer]
#
#                                               actions  no_action_metric  \
# 0                             [Rattenbiss, Pestwolke]             21.50
# 1   [Reißzahnbiss, Schädelbrumme, Abyssaler Nebelh...            137.00
# 2                       [Stachelschuss, Stachelwalze]             26.40
# 3               [Würgegriff, Netzschuss, Säurespeier]             32.20
# 4                            [Spektraler Biss, Fluch]             36.80
# 5                           [Würgegriff, Klingenhieb]             24.60
# 6   [Schurkischer Angriff, Schneller Hieb, Blendgr...             28.60
# 7   [Klingenhieb, Brutale Hiebe, Zerquetschen, Ber...             37.00
# 8   [Elektrisierender Stoß, Blitzstrahl, Überladun...             28.80
# 9          [Blutiger Schlag, Blutige Rache, Blutwoge]             68.00
# 10               [Bohrschnabel, Kreischen, Sturzflug]             25.90
# 11  [Geistergeweih, Kältestrahl, Frostige Hufe, Ei...             88.75
# 12  [Schädelbrumme, Schnapper, Regeneration, Giftz...             34.05
# 13                         [Schädelbrumme, Quälgeist]             21.05
# 14  [Dämonischer Hieb, Schwarze Welle, Schattenbar...             58.80
# 15                          [Frostiger Nebelschleier]             25.50
# 16  [Frostiger Vampirbiss, Frostiger Flügelschlag,...             14.60
# 17   [Spektrale Klinge, Eisiger Sturm, Eisige Ketten]             58.10
# 18  [Greifzangen, Steinsalve, Donnernde Explosion,...            147.00
# 19               [Klingenhieb, Fluch, Schneller Hieb]             12.90
# 20  [Schmetternde Faust, Gedankenpein, Telekinetis...             53.15
# 21  [Feuerballwurf, Wurzelgriff, Verschlingen, Fla...             20.80
# 22  [Wasserpeitsche, Gedankenpein, Flutwelle, Geis...             65.40
# 23                  [Knüppelschlag, Rabiater Angriff]             10.60
# 24  [Klingenklatscher, Dornenstoß, Schalenramme, E...             30.00
# 25                      [Bohrschnabel, Reptilienbiss]             41.60
# 26  [Klingenhieb, Schwanzschlag, Wasserstrahl, Str...             43.20
# 27  [Tentakelpeitsche, Würgegriff, Tintenwolke, Wa...             36.60
# 28  [Sturzflug, Kreischen, Giftzahn, Kratzer, Stür...             60.40
# 29  [Kurzschwertschlag, Großschwerthieb, Lanzensto...             61.40
# 30  [Brutale Hiebe, Beilhieb, Schwanzschlag, Schne...             36.30
# 31  [Reißzahnbiss, Schädelbrumme, Quadro-Giftspore...            107.00
# 32  [Blitzstrahl, Elektrisierender Stoß, Tentakelp...             48.40
# 33  [Feuriger Vampirbiss, Flammender Flügelschlag,...             14.60
#
#     difficulty_rating
# 0               55.50
# 1              183.00
# 2               46.40
# 3               70.20
# 4               65.80
# 5               37.60
# 6               46.78
# 7               86.00
# 8               50.07
# 9              105.75
# 10              45.90
# 11             126.93
# 12              60.05
# 13              47.05
# 14              81.89
# 15              67.50
# 16              37.60
# 17              83.01
# 18             187.71
# 19              41.90
# 20              80.06
# 21              43.25
# 22              98.58
# 23              27.60
# 24              60.00
# 25              53.60
# 26              61.47
# 27              54.60
# 28              81.31
# 29              87.40
# 30              85.30
# 31             151.00
# 32              69.40
# 33              37.60

# %%
# Step 5: Norm difficulty on Goblins as reference point
goblin_difficulty_rating = enemies_df[enemies_df['name'] == "Goblin"]["difficulty_rating"].iloc[0]
goblin_stats_rating = enemies_df[enemies_df['name'] == "Goblin"]["no_action_metric"].iloc[0]
enemies_df['difficulty_rating_normed'] = round(
    enemies_df['difficulty_rating'] / goblin_difficulty_rating, 2)
enemies_df['stats_rating_normed'] = round(
    enemies_df['no_action_metric'] / goblin_stats_rating, 2)
# only for testing
# enemies_df

# df that is presented to the user
presenting_df = enemies_df[['name', 'difficulty_rating_normed', 'stats_rating_normed']]
presenting_df
# Out:
#                  name  difficulty_rating_normed  stats_rating_normed
# 0       Abwassernager                      2.01                 2.03
# 1             Abyssor                      6.63                12.92
# 2           Aerocacti                      1.68                 2.49
# 3            Arachnia                      2.54                 3.04
# 4              Babasu                      2.38                 3.47
# 5     Bandagenwandler                      1.36                 2.32
# 6              Bandit                      1.69                 2.70
# 7      Bestienkrieger                      3.12                 3.49
# 8        Blitzschneck                      1.81                 2.72
# 9     Blutstahlritter                      3.83                 6.42
# 10       Bohrschnabel                      1.66                 2.44
# 11           Boreanos                      4.60                 8.37
# 12    Drachenmäulchen                      2.18                 3.21
# 13           Drösling                      1.70                 1.99
# 14  Dämonenabkömmling                      2.97                 5.55
# 15         Eiseskälte                      2.45                 2.41
# 16         Eisflügler                      1.36                 1.38
# 17           Eisgeist                      3.01                 5.48
# 18        Elektrabrax                      6.80                13.87
# 19          Erzknecht                      1.52                 1.22
# 20     Fingerkrabller                      2.90                 5.01
# 21        Flammengrün                      1.57                 1.96
# 22      Gezeitenblick                      3.57                 6.17
# 23             Goblin                      1.00                 1.00
# 24        Klinguschel                      2.17                 2.83
# 25            Krokuin                      1.94                 3.92
# 26   Meeresschlächter                      2.23                 4.08
# 27             Octark                      1.98                 3.45
# 28      Riesenflügler                      2.95                 5.70
# 29             Ritter                      3.17                 5.79
# 30       Stahlschuppe                      3.09                 3.42
# 31          Tetravora                      5.47                10.09
# 32          Voltfaden                      2.51                 4.57
# 33      Zunderflügler                      1.36                 1.38
